# %% [markdown]
# # Multi-Agent Collaboration and Orchestration using LangGraph for Mistral Models
#
# ## Introduction
#
# This notebook demonstrates a sophisticated multi-agent system built with LangGraph and powered by Amazon Bedrock and Mistral. This Multi-Agent City Information System provides comprehensive information about a city, including events, weather, activities, and recommendations.
#
# ## Goals and Expected Outcomes
#
# This notebook aims to demonstrate and achieve the following:
#
# 1. Integration and Orchestration:
#    - Showcase the integration of Mistral with AWS services for building complex LLM applications.
#    - Demonstrate the power of LangGraph in creating and orchestrating multi-agent systems.
#    - Illustrate the integration of various data sources and APIs within a multi-agent framework.
#
# 2. Comprehensive City Information System:
#    Create a multi-agent system that delivers:
#    - Upcoming events information:
#      * Retrieved from a local SQLite database
#      * Searched online using the Tavily API when local data is unavailable
#    - Current weather information and analysis using the OpenWeatherMap API
#    - Suggested activities based on events and weather conditions
#    - Outfit recommendations considering the weather
#
# 3. System Flexibility and Adaptability:
#    - Demonstrate the system's ability to handle varying levels of available information across different cities.
#    - Showcase the seamless switching between local and online data sources.
#
# 4. Analysis and Synthesis:
#    - Provide a final analysis that combines event and weather information into coherent and useful recommendations for city visitors or residents.
#
# ## Benefits of Using Multi-Agents
#
# - **Modularity**: Each agent focuses on a specific task, making the system easier to maintain and extend.
# - **Flexibility**: Agents can be easily added, removed, or modified without affecting the entire system.
# - **Scalability**: The system can handle complex workflows by distributing tasks among multiple agents.
# - **Improved Performance**: Parallel processing of tasks by different agents can lead to faster results.
# - **Specialization**: Each agent can be optimized for its specific task, improving overall system efficiency.
#
# ## Why Use LangGraph?
#
# LangGraph is a powerful framework for building multi-agent systems:
#
# - Provide a structured way to define and manage the flow of information between agents.
# - Offer built-in support for state management and checkpointing.
# - Allow for easy visualization of the agent workflow.
# - Integrate well with large language models and other AI tools.
# - Support conditional routing, enabling dynamic workflow adjustments based on intermediate results.
#
# ## System Components
#
# Our multi-agent system consists of the following components:
#
# 1. **EventsDB Tool**: Queries a local SQLite database for event information.
# 2. **Search Tool**: Utilizes the Tavily API to search for online event information when local data is unavailable.
# 3. **Weather Tool**: Fetches current weather data using the OpenWeatherMap API.
# 4. **Analysis Node**: Synthesizes information from other agents to provide comprehensive recommendations.
#
# ## Key Technologies Used
#
# - **Amazon Bedrock**: For accessing the Mistral large language model
# - **LangGraph**: For orchestrating the multi-agent system
# - **Langchain**: For building the RAG pipeline and other LLM interactions
# - **SQLite**: For local event database storage
# - **Tavily API**: For online event searches
# - **OpenWeatherMap API**: For current weather data
#
# By the end of this notebook, you'll have a clear understanding of how to build a sophisticated multi-agent system that can process and synthesize information from various sources, adapting to different scenarios and data availability to provide valuable insights about a city.

# %% [markdown]
# ## Environment Setup
#
# Before we begin, ensure you have the necessary permissions and credentials to access Amazon Bedrock and other AWS services. You'll also need to install the required Python libraries.

# %%
# Install required packages
# %pip install --upgrade --quiet --no-cache-dir --force-reinstall \
    boto3 \
    botocore \
    faiss-cpu \
    ipython \
    langchain \
    langchain-community \
    langgraph \
    pandas \
    pydantic \
    pyowm \
    tavily-python

# %% [markdown]
# ## Setup and Requirements
#
# Sign up for the following API keys as they will be used by the agents throughout this notebook:
#
# a. **Tavily Search API** is used for performing web searches to find up-to-date information about events in various cities.
# :
#    - Visit [Tavily AI](https://tavily.com/) and sign up for an account.
#    - Once registered, navigate to your dashboard to find your API key.
#    - Set the environment variable `TAVILY_API_KEY` with your Tavily API key.
#
# b. **OpenWeatherMap API** provides current weather data for cities worldwide, which is used in our weather analysis.
#
#    - Go to [OpenWeatherMap](https://openweathermap.org/) and create an account.
#    - After signing up, go to your account dashboard and find your API key.
#    - Set the environment variable `OPENWEATHERMAP_API_KEY` with your OpenWeatherMap API key.
#
#
# Now, let's import the necessary libraries and set up our environment:

# %%
# Standard library imports
import json
import logging
import os
import sys
import traceback
from datetime import datetime
from typing import List, Dict

# AWS and third-party imports
import boto3
import pandas as pd
import sqlite3
from IPython.display import Image, display
from pydantic import BaseModel, Field
from tavily import TavilyClient

# LangChain imports
from langchain.docstore.document import Document
from langchain.vectorstores import FAISS
from langchain_community.embeddings import BedrockEmbeddings
from langchain_community.utilities import OpenWeatherMapAPIWrapper
from langchain_core.runnables.graph import MermaidDrawMethod
from langchain_text_splitters import RecursiveJsonSplitter

# LangGraph imports
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolInvocation
from langgraph.checkpoint import MemorySaver

# Set up logging and API keys
logging.basicConfig(level=logging.INFO, stream=sys.stdout, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

os.environ["OPENWEATHERMAP_API_KEY"] = "your_openweathermap_api_key"
os.environ['TAVILY_API_KEY'] = 'your_tavily_api_key'
AWS_REGION = "us-west-2"
DEFAULT_MODEL = "mistral.mistral-large-2407-v1:0"
DEFAULT_EMBEDDINGS = "amazon.titan-embed-text-v2:0"

# Initialize Bedrock client
bedrock_client = boto3.client(service_name='bedrock-runtime', region_name=AWS_REGION)

# Define state structure using Pydantic
class State(BaseModel):
    city: str
    messages: List[Dict] = Field(default_factory=list)
    events_result: str = ""
    search_result: str = ""
    weather_info: Dict[str, str] = Field(default_factory=dict)
    analysis_result: str = ""
    restaurant_recommendations: str = ""

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## Use Case Explanation
#
# This system takes a city name as input and provides the following information:
#
# 1. **Events**: It searches a local database and online sources for upcoming events in the city.
# 2. **Weather**: It fetches current weather information for the city.
# 3. **Activities**: Based on the events and weather, it suggests suitable activities.
# 4. **Outfit Recommendations**: Considering the weather, it provides clothing suggestions.
# 5. **Dining Options**: It recommends highly-rated restaurants in the city.
#
# This information is particularly useful for travelers or locals planning their activities.

# %% [markdown]
# ## Data Preparation and Database Initialization
#
# In this section, we'll prepare our data sources and initialize our local database. We're using a SQLite database to store local event information and the Yelp dataset for restaurant recommendations.
#
# ### Event Database Setup
#
# Let's load our event data from a JSON file and initialize our SQLite database:

# %%
# Load the JSON file directly into a DataFrame
df = pd.read_json('./data/eventsDB_data.json')

# Initialize the SQLite database with the DataFrame
def initialize_database(db_path, df):
    conn = sqlite3.connect(db_path)
    df.to_sql('local_events', conn, if_exists='replace', index=False)
    conn.close()
    print(f"Database initialized with {len(df)} events.")

# Initialize the database
db_path = 'local_info.db'
initialize_database(db_path, df)
# Out:
# Database initialized with 54 events.

# %% [markdown]
# ### Restaurant Data Preparation
#
# For restaurant recommendations using RAG, we're using a subset of the Yelp dataset. You can download the full dataset from [Yelp's official website](https://www.yelp.com/dataset). For this example, we'll use a small subset of the data. The Yelp dataset is a rich source of business, review, and user data, ideal for academic research and learning purposes. It's available as JSON files and can be used for various applications, including natural language processing tasks and database management practice. Let's prepare this data:

# %%
def prepare_restaurants_dataset():
    # Define the target directory
    target_directory = './data'

    # Create the full paths using os.path.join()
    zip_file = os.path.join(target_directory, 'yelp_academic_dataset_business.json.zip')
    json_file = os.path.join(target_directory, 'yelp_academic_dataset_business.json')
    output_file = os.path.join(target_directory, 'first_500_businesses.json')

    # Ensure the target directory exists
    os.makedirs(target_directory, exist_ok=True)
    
    # Unzip and extract first 500 rows into the target directory
    print("Unzipping the file...")
    os.system(f"unzip -o {zip_file} -d {target_directory}")

    print("Extracting first 500 rows...")
    os.system(f"head -n 500 {json_file} > {output_file}")

    # Verify the output file
    if os.path.exists(output_file):
        print(f"Successfully created {output_file}")
        print(f"File size: {os.path.getsize(output_file)} bytes")
    else:
        print("Failed to create output file")
        return None

    # Optional: Remove the large JSON file to save space
    os.remove(json_file)
    print(f"Removed {json_file}")

    # Load the JSON file into a pandas DataFrame
    print("Loading data into DataFrame...")
    df = pd.read_json(output_file, lines=True)
    return df

# Prepare restaurant data
restaurant_df = prepare_restaurants_dataset()
if restaurant_df is not None:
    print("Restaurant data prepared successfully!")
else:
    print("Failed to prepare restaurant data. Exiting.")
    exit(1)
# Out:
# Unzipping the file...
# Archive:  ./data/yelp_academic_dataset_business.json.zip
#   inflating: ./data/yelp_academic_dataset_business.json
# Extracting first 500 rows...
# Successfully created ./data/first_500_businesses.json
# File size: 398324 bytes
# Removed ./data/yelp_academic_dataset_business.json
# Loading data into DataFrame...
# Restaurant data prepared successfully!

# %% [markdown]
# ## Vector Database Creation for RAG
#
# To enable efficient retrieval of restaurant information, we'll create a vector database using FAISS. This forms the basis of our RAG system for restaurant recommendations.

# %%
def create_vector_store(df):
    # Convert DataFrame to list of dictionaries
    print("Converting DataFrame to list of dictionaries...")
    data = df.to_dict('records')

    # Use RecursiveJsonSplitter
    print("Splitting documents...")
    json_splitter = RecursiveJsonSplitter(max_chunk_size=1000)

    split_texts = []
    for item in data:
        split_texts.extend(json_splitter.split_text(json_data=item, convert_lists=True))

    # Convert split texts to documents
    split_documents = [Document(page_content=text) for text in split_texts]

    # Initialize Bedrock Embeddings
    print("Initializing embeddings...")
    bedrock_embeddings = BedrockEmbeddings(
        region_name=AWS_REGION,
        model_id=DEFAULT_EMBEDDINGS
    )

    # Create vector store
    print("Creating vector store...")
    vectorstore = FAISS.from_documents(split_documents, bedrock_embeddings)
    return vectorstore

# Create vector store
vectorstore = create_vector_store(restaurant_df)
print("Vector store created successfully!")
# Out:
# Converting DataFrame to list of dictionaries...
# Splitting documents...
# Initializing embeddings...
# Creating vector store...
# 2024-07-06 00:28:36,308 - INFO - Loading faiss with AVX512 support.
# 2024-07-06 00:28:36,348 - INFO - Successfully loaded faiss with AVX512 support.
# Vector store created successfully!

# %% [markdown]
# ### Text Generation Function
#
# This function serves as the core of our agents, allowing them to generate text using the Mistral model. It leverages the Amazon Bedrock Converse API, which supports text generation, streaming, and external function calling (tools). For more information, see the [Amazon Bedrock Tool Use documentation](https://docs.aws.amazon.com/bedrock/latest/userguide/tool-use.html) and the [Amazon Bedrock Conversation Inference documentation](https://docs.aws.amazon.com/bedrock/latest/userguide/conversation-inference.html#conversation-inference-call).
#
# The function works as follows:
# 1. Sends a user message to the Mistral model via the Bedrock Converse API.
# 2. Handles tool use requests by invoking the appropriate tool and incorporating the results into the conversation.
# 3. Continues the conversation until a final response is generated.

# %%
def generate_text(bedrock_client, model_id, tool_config, input_text):
    print("\nGenerating text with model:", model_id)
    
    is_mistral_model = model_id.startswith("mistral.")
    
    messages = [{
        "role": "user",
        "content": [{"text": input_text}]
    }]

    inference_config = {
        "temperature": 0.5,
        "topP": 0.9,
        "maxTokens": 8192
    } if is_mistral_model else {}

    kwargs = {
        "modelId": model_id,
        "messages": messages,
        "inferenceConfig": inference_config
    }

    if tool_config:
        kwargs["toolConfig"] = tool_config

    tool_result = None  # Initialize tool_result

    while True:
        response = bedrock_client.converse(**kwargs)
        output_message = response['output']['message']
        messages.append(output_message)  # Add assistant's response to messages
        
        stop_reason = response.get('stopReason')

        if stop_reason == 'tool_use' and tool_config:
            tool_use = output_message['content'][0]['toolUse']
            tool_use_id = tool_use['toolUseId']
            tool_name = tool_use['name']
            tool_input = tool_use['input']

            try:
                if tool_name == 'get_upcoming_events':
                    tool_result = local_info_database_tool(tool_input['city'])
                    json_result = json.dumps({"events": tool_result})
                elif tool_name == 'get_city_weather':
                    weather = OpenWeatherMapAPIWrapper()
                    tool_result = weather.run(tool_input['city'])
                    json_result = json.dumps({"weather": tool_result})
                elif tool_name == 'search_and_summarize_events':
                    tool_result = search_and_summarize(tool_input['city'])
                    json_result = json.dumps({"events": tool_result})
                else:
                    raise ValueError(f"Unknown tool: {tool_name}")
                
                tool_response = {
                    "toolUseId": tool_use_id,
                    "content": [{"json": json.loads(json_result)}]
                }
            except Exception as e:
                print(f"Error using tool {tool_name}: {str(e)}")
                tool_response = {
                    "toolUseId": tool_use_id,
                    "content": [{"text": f"Error using {tool_name}: {str(e)}"}],
                    "status": "error"
                }
                tool_result = None  # Set tool_result to None in case of an error

            messages.append({
                "role": "user",
                "content": [{"toolResult": tool_response}]
            })
            
            # Update kwargs with new messages
            kwargs["messages"] = messages
        else:
            break

    return output_message, tool_result

# %% [markdown]
# ### Local Database Query Function
#
# This function queries the local SQLite database for event information. Used by the **Event Database Agent**(`eventsDB_tool` function):

# %%
def local_info_database_tool(city: str) -> str:
    conn = sqlite3.connect(db_path)
    query = """
        SELECT event_name, event_date, description 
        FROM local_events 
        WHERE city = ?
        ORDER BY event_date
        LIMIT 3
    """
    df = pd.read_sql_query(query, conn, params=(city,))
    conn.close()
    print(df)
    if not df.empty:
        events = df.apply(lambda row: f"{row['event_name']} on {row['event_date']}: {row['description']}", axis=1).tolist()
        return "\n".join(events)
    else:
        return f"No upcoming events found for {city}."

# %% [markdown]
# ### Online Search Function
#
# This function performs an online search for events using the Tavily API. Used by the **Search Agent**(`search_tool` function):

# %%
def search_and_summarize(city: str) -> str:
    client = TavilyClient(api_key=os.environ['TAVILY_API_KEY'])
    query = f"What are the upcoming events in {city}?"
    response = client.search(query, search_depth="advanced")
    results_content = "\n\n".join([result['content'] for result in response['results']])
    return results_content

# %% [markdown]
# ### Restaurant Recommendation Function
#
# This function uses the RAG system to provide restaurant recommendations. Used by the **Restaurant Recommendation Agent**(`query_restaurants_node` function):

# %%
def query_restaurants_RAG(city):
    query = f"Find restaurants with 4 stars or higher ratings in {city} and describe their key features"
    print(f"\nPerforming query: {query}")
    
    relevant_docs = vectorstore.similarity_search(query, k=50)

    high_rated_docs = []
    for doc in relevant_docs:
        try:
            content = json.loads(doc.page_content)
            if content.get('stars', 0) >= 4 and content.get('city', '').lower() == city.lower():
                high_rated_docs.append(doc)
        except json.JSONDecodeError:
            continue

    high_rated_docs = high_rated_docs[:5]

    if high_rated_docs:
        print(f"\nTop {len(high_rated_docs)} relevant documents for high-rated restaurants in {city}:")
        for i, doc in enumerate(high_rated_docs, 1):
            print(f"\nDocument {i}:")
            print(doc.page_content)
        context = "\n\n".join([doc.page_content for doc in high_rated_docs])
    else:
        print(f"No high-rated restaurants found in {city}.")
        context = ""

    prompt = f"""Task: Provide information about highly-rated restaurants (4 stars and above) in {city}.

    Instructions:
    1. If the following context contains information about restaurants in {city}, describe the key features that contribute to their high ratings. Consider aspects such as cuisine type, ambiance, service, price range, and any standout characteristics.
    2. Only use the information provided in the context. If certain information is not available, state that it's not mentioned.
    3. If no information is provided in the context, respond with: "I'm sorry, but I couldn't find any information about highly-rated restaurants in {city}."
    4. Do not generate or invent any information about restaurants if none is provided in the context.

    Context:
    {context}

    Please provide your response based on these instructions:"""

    output_message, _ = generate_text(bedrock_client, DEFAULT_MODEL, None, prompt)
    
    if 'content' in output_message and len(output_message['content']) > 0:
        response_content = output_message['content'][0]['text']
    else:
        response_content = f"I'm sorry, but I couldn't find any information about highly-rated restaurants in {city}."
    
    print("\nGenerated response:")
    print(response_content)
    
    return response_content

# %% [markdown]
# ## Multi-agent System Definitions
#
# Our multi-agent system is composed of several specialized nodes, each responsible for a specific task. These nodes are then organized into a workflow using LangGraph. Here's an overview of the key components:
#
# ### Agent Functions
#
# 1. **eventsDB_tool**: Queries the local database for upcoming events in a specified city.
# 2. **search_tool**: Performs an online search for events when local data is unavailable.
# 3. **weather_tool**: Fetches current weather information for the specified city.
# 4. **query_restaurants_node**: This agent uses our RAG system to provide restaurant recommendations.
# 5. **analysis_node**: Synthesizes event and weather information to provide recommendations.

# %% [markdown]
# ### 1. Event Database Agent
#
# This agent retrieves event information from our local database:

# %%
def eventsDB_tool(state: State) -> State:
    print("\n" + "*" * 50)
    print("eventsDB_tool function called")
    print("*" * 50)
    tool_config = {
        "tools": [
            {
                "toolSpec": {
                    "name": "get_upcoming_events",
                    "description": "Get upcoming events for a specific city from the local database",
                    "inputSchema": {
                        "json": {
                            "type": "object",
                            "properties": {
                                "city": {
                                    "type": "string",
                                    "description": "The name of the city to look up events for"
                                }
                            },
                            "required": ["city"]
                        }
                    }
                }
            }
        ]
    }
    
    input_text = f"Get upcoming events for {state.city} from the local database"
    output_message, tool_result = generate_text(bedrock_client, DEFAULT_MODEL, tool_config, input_text)
    
    if tool_result:
        state.events_result = tool_result
    else:
        state.events_result = "No event information available in the local database."
    
    print(f"Events set to: {state.events_result}")
    return state

# %% [markdown]
# ### 2. Search Agent
#
# When local event information is not available in the database, this agent performs an online search:

# %%
def search_tool(state: State) -> State:
    print("\n" + "*" * 50)
    print("search_tool function called")
    print("*" * 50)
    tool_config = {
        "tools": [
            {
                "toolSpec": {
                    "name": "search_and_summarize_events",
                    "description": "Search for and summarize upcoming events for a specific city",
                    "inputSchema": {
                        "json": {
                            "type": "object",
                            "properties": {
                                "city": {
                                    "type": "string",
                                    "description": "The name of the city to look up events for"
                                }
                            },
                            "required": ["city"]
                        }
                    }
                }
            }
        ]
    }
    
    input_text = f"Search for and summarize upcoming events in {state.city}"
    output_message, tool_result = generate_text(bedrock_client, DEFAULT_MODEL, tool_config, input_text)
    
    if tool_result:
        state.search_result = tool_result
    else:
        state.search_result = "No event information available from online search."
    
    print(f"Search result set to: {state.search_result[:500]}...")  # Print first 500 characters
    return state

# %% [markdown]
# ### 3. Weather Agent
#
# This agent fetches current weather information for the specified city:

# %%
def weather_tool(state: State) -> State:
    print("\n" + "*" * 50)
    print("weather_tool function called")
    print("*" * 50)
    tool_config = {
        "tools": [
            {
                "toolSpec": {
                    "name": "get_city_weather",
                    "description": "Get current weather information for a specific city",
                    "inputSchema": {
                        "json": {
                            "type": "object",
                            "properties": {
                                "city": {
                                    "type": "string",
                                    "description": "The name of the city to look up weather for"
                                }
                            },
                            "required": ["city"]
                        }
                    }
                }
            }
        ]
    }
    
    input_text = f"Get current weather for {state.city}"
    output_message, tool_result = generate_text(bedrock_client, DEFAULT_MODEL, tool_config, input_text)
    
    if tool_result:
        state.weather_info = {"city": state.city, "weather": tool_result}
    else:
        state.weather_info = {"city": state.city, "weather": "Weather information not available."}
    
    print(f"Weather info set to: {state.weather_info}")
    return state

# %% [markdown]
# ### 4. Restaurant Recommendation Agent
#
# This agent uses our RAG system to provide restaurant recommendations:

# %%
def query_restaurants_node(state: State) -> State:
    print("\n" + "*" * 50)
    print("query_restaurants_node function called")
    print("*" * 50)
    state.restaurant_recommendations = query_restaurants_RAG(state.city)
    print(f"Restaurant recommendations set for {state.city}")
    return state

# %% [markdown]
# ### 5. Analysis Agent
#
# This agent synthesizes all the gathered information to provide a comprehensive analysis:

# %%
def analysis_node(state: State) -> State:
    print("\n" + "*" * 50)
    print("analysis_node function called")
    print("*" * 50)
    input_text = f"""Analyze the following information about {state.city}:

Events from local database: {state.events_result}
Events from online search: {state.search_result}
Weather: {state.weather_info['weather']}
Restaurant Recommendations: {state.restaurant_recommendations}

Please provide:
1. A brief weather analysis
2. Suggested activities based on the weather and events (from both local and online sources)
3. Outfit recommendations considering the weather
4. A summary of recommended restaurants and dining options"""

    output_message, _ = generate_text(bedrock_client, DEFAULT_MODEL, None, input_text)

    if 'content' in output_message and len(output_message['content']) > 0:
        state.analysis_result = output_message['content'][0]['text']
    else:
        state.analysis_result = "Unable to generate analysis."

    state.messages.append({"role": "assistant", "content": [{"text": state.analysis_result}]})
    
    print(f"Analysis result: {state.analysis_result[:500]}...")  # Print first 500 characters
    return state

# %% [markdown]
# ## LangGraph Workflow Construction
#
# Now that we have defined our agents, let's construct the LangGraph workflow that will orchestrate their interactions. The `build_graph` function creates the workflow structure:
#
# 1. Adds nodes for each tool (eventsDB, search, weather, restaurant recommendations, and analysis).
# 2. Sets the entry point to the eventsDB_tool.
# 3. Adds a conditional edge from eventsDB_tool to either search_tool or weather_tool.
# 4. Connects the remaining nodes in sequence.
# 5. Builds the graph and compiles the workflow.
# 6. Visualize the graph.

# %%
# Define the graph
def build_graph():
    workflow = StateGraph(State)

    workflow.add_node("eventsDB_tool", eventsDB_tool)
    workflow.add_node("search_tool", search_tool)
    workflow.add_node("weather_tool", weather_tool)
    workflow.add_node("query_restaurants_RAG", query_restaurants_node)
    workflow.add_node("analysis", analysis_node)

    workflow.set_entry_point("eventsDB_tool")

    # Add conditional edge
    def route_events(state):
        print(f"Routing events. Current state: {state}")
        print(f"Events content: '{state.events_result}'")
        if f"No upcoming events found for {state.city}" in state.events_result:
            print("No events found in local DB. Routing to search_tool.")
            return "search_tool"
        else:
            print("Events found in local DB. Routing to weather_tool.")
            return "weather_tool"

    workflow.add_conditional_edges(
        "eventsDB_tool",
        route_events,
        {
            "search_tool": "search_tool",
            "weather_tool": "weather_tool"
        }
    )

    workflow.add_edge("search_tool", "weather_tool")
    workflow.add_edge("weather_tool", "query_restaurants_RAG")
    workflow.add_edge("query_restaurants_RAG", "analysis")
    workflow.add_edge("analysis", END)
    
    # Initialize memory to persist state between graph runs
    checkpointer = MemorySaver()

    # Compile the workflow
    app = workflow.compile(checkpointer=checkpointer)
    print("Workflow compiled successfully")
        
    # Visualize the graph
    display(
        Image(
            app.get_graph().draw_mermaid_png(
                draw_method=MermaidDrawMethod.API
            )
        )
    )

    #return app and checkpointer
    return app, checkpointer

print("Graph construction function defined.")
# Out:
# Graph construction function defined.

# %% [markdown]
# ## Main Execution
#
# Finally, let's define our main execution function that will run the entire workflow. The used function orchestrates the entire process:
#
# 1. Initializes the state with the specified city.
# 2. Streams the events through the workflow.
# 3. Retrieves and displays the final analysis and recommendations.

# %%
# Main execution
def main(city: str):
    try:
        print(f"Starting main execution for city: {city}")
        app, checkpointer = build_graph()
        print("Graph built successfully")
                
        initial_state = State(
            city=city,
            messages=[{"role": "user", "content": [{"text": f"What's happening in {city} and what should I wear?"}]}],
            events_result="",
            weather_info={},
            analysis_result="",
            search_result="",
            restaurant_recommendations=""
        )

        # Configuration for the stream and checkpointer
        config = {
            "recursion_limit": 150,
            "configurable": {
                "thread_id": "42"  # Using string as thread_id
            }
        }

        print("Starting to stream events")
        # Stream the events with the required configurable key
        events = app.stream(
            initial_state,
            config=config
        )

        for output in events:
            if "__end__" not in output:
                print(f"\nIntermediate output: {output}")

        # Access the final state from the checkpointer
        final_state_dict = checkpointer.get(config=config)

        # Print the final response from the assistant
        if 'channel_values' in final_state_dict and 'messages' in final_state_dict['channel_values']:
            messages = final_state_dict['channel_values']['messages']
            if messages and isinstance(messages, list):
                final_message = messages[-1]
                if final_message.get("role") == "assistant":
                    print("\nFinal response from the assistant:")
                    print(json.dumps(final_message["content"], indent=2))
                else:
                    print("\nNo final response from the assistant found in the messages.")
            else:
                print("\nNo valid messages found in the final state.")
        else:
            print("\nNo messages found in the final state.")

        # Print the full final state from checkpointer
        print("\nFinal state from checkpointer:")
        print(json.dumps(final_state_dict, indent=2))
        
    except Exception as e:
        print(f"An error occurred in main execution: {str(e)}")
        print(traceback.format_exc())

print("Main execution function defined.")
# Out:
# Main execution function defined.

# %% [markdown]
# ## Results and Analysis
#
# Let's run our multi-agent system for three different cities: Tampa, Philadelphia, and New York. Each case demonstrates different aspects of our system's functionality.
#
# ### Example 1: Tampa, Florida

# %%
if __name__ == "__main__":
    city = "Tampa"
    print(f"Starting script execution for city: {city}")
    main(city)
# Out:
# Starting script execution for city: Tampa
# Starting main execution for city: Tampa
# Workflow compiled successfully
# Graph built successfully
# Starting to stream events
#
# **************************************************
# eventsDB_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Empty DataFrame
# Columns: [event_name, event_date, description]
# Index: []
# Events set to: No upcoming events found for Tampa.
# Routing events. Current state: city='Tampa' messages=[{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}] events_result='No upcoming events found for Tampa.' search_result='' weather_info={} analysis_result='' restaurant_recommendations=''
# Events content: 'No upcoming events found for Tampa.'
# No events found in local DB. Routing to search_tool.
#
# Intermediate output: {'eventsDB_tool': {'city': 'Tampa', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}], 'events_result': 'No upcoming events found for Tampa.', 'search_result': '', 'weather_info': {}, 'analysis_result': '', 'restaurant_recommendations': ''}}
#
# **************************************************
# search_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Search result set to: We're your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what's happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!
#
# Fri • 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. J...
#
# Intermediate output: {'search_tool': {'city': 'Tampa', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}], 'events_result': 'No upcoming events found for Tampa.', 'search_result': 'We\'re your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what\'s happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!\n\nFri • 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. Jun 14. Fri • 7:00pm. Communion After Dark Presents: SITD, 00tz 00tz, and Retractor in Tampa. New World Music Hall - Tampa, FL.\n\nTue, Dec 5 •\n6:30 PM\nArmature Works\nCheck ticket price on event\nAn Evening with Omari Dillard: Soul Violinist\nFri, Dec 8 •\n8:00 PM\nCentro Asturiano de Tampa\nCheck ticket price on event\nOnline Events\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : 9th and 10th December\nSat, Dec 9 •\n12:30 PM\nGMT\nCheck ticket price on event\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : Today • 6:00 PM\nMacDill Park on the Riverwalk\nCheck ticket price on event\nYoga with Kodawari Studios\nTomorrow • 9:30 AM\nArmature Works\nCheck ticket price on event\nNardo Wick at Club Skye\nTomorrow • 9:00 PM\nClub Skye, East 8th Avenue, Tampa, FL, USA\nCheck ticket price on event\nSO LIT SUNDAYS\nTomorrow • 4:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nSite Navigation\nUse Eventbrite\nPlan Events\nFind Events\nConnect With Us Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchange\nCheck ticket price on event\nFemmes & Follies: 10th Anniversary Show\nSat, Dec 2 •\n7:00 PM\nThe Ritz Ybor\nCheck ticket price on event\nCigar Pxrn 6 Year Lifestyle Celebration\nSat, Dec 2 •\n1:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nArmature Works Book Club - December 5th\n Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchange\nCheck t ...
#
# **************************************************
# weather_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Weather info set to: {'city': 'Tampa', 'weather': "In Tampa, the current weather is as follows:\nDetailed status: moderate rain\nWind speed: 6.17 m/s, direction: 110°\nHumidity: 87%\nTemperature: \n  - Current: 27.93°C\n  - High: 30.1°C\n  - Low: 26.0°C\n  - Feels like: 33.02°C\nRain: {'1h': 0.49}\nHeat index: None\nCloud cover: 40%"}
#
# Intermediate output: {'weather_tool': {'city': 'Tampa', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}], 'events_result': 'No upcoming events found for Tampa.', 'search_result': 'We\'re your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what\'s happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!\n\nFri • 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. Jun 14. Fri • 7:00pm. Communion After Dark Presents: SITD, 00tz 00tz, and Retractor in Tampa. New World Music Hall - Tampa, FL.\n\nTue, Dec 5 •\n6:30 PM\nArmature Works\nCheck ticket price on event\nAn Evening with Omari Dillard: Soul Violinist\nFri, Dec 8 •\n8:00 PM\nCentro Asturiano de Tampa\nCheck ticket price on event\nOnline Events\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : 9th and 10th December\nSat, Dec 9 •\n12:30 PM\nGMT\nCheck ticket price on event\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : Today • 6:00 PM\nMacDill Park on the Riverwalk\nCheck ticket price on event\nYoga with Kodawari Studios\nTomorrow • 9:30 AM\nArmature Works\nCheck ticket price on event\nNardo Wick at Club Skye\nTomorrow • 9:00 PM\nClub Skye, East 8th Avenue, Tampa, FL, USA\nCheck ticket price on event\nSO LIT SUNDAYS\nTomorrow • 4:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nSite Navigation\nUse Eventbrite\nPlan Events\nFind Events\nConnect With Us Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchange\nCheck ticket price on event\nFemmes & Follies: 10th Anniversary Show\nSat, Dec 2 •\n7:00 PM\nThe Ritz Ybor\nCheck ticket price on event\nCigar Pxrn 6 Year Lifestyle Celebration\nSat, Dec 2 •\n1:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nArmature Works Book Club - December 5th\n Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchange\nCheck  ...
#
# **************************************************
# query_restaurants_node function called
# **************************************************
#
# Performing query: Find restaurants with 4 stars or higher ratings in Tampa and describe their key features
#
# Top 5 relevant documents for high-rated restaurants in Tampa:
#
# Document 1:
# {"business_id": "uI9XODGY_2_ieTE6xJ0myw", "name": "Roman Forum", "address": "10440 N Dale Mabry Hwy", "city": "Tampa", "state": "FL", "postal_code": "33618", "latitude": 28.0462028173, "longitude": -82.5050526736, "stars": 4.0, "review_count": 23, "is_open": 0, "attributes": {"BusinessParking": "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", "BikeParking": "False", "OutdoorSeating": "True", "RestaurantsDelivery": "False", "GoodForKids": "True", "RestaurantsTakeOut": "True", "BusinessAcceptsCreditCards": "True", "Caters": "True", "NoiseLevel": "u'quiet'", "WiFi": "'no'", "HasTV": "True", "Ambience": "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}", "RestaurantsAttire": "u'casual'", "RestaurantsReservations": "True", "Alcohol": "u'full_bar'", "RestaurantsGoodForGroups": "True", "RestaurantsPriceRange2": "2"}}
#
# Document 2:
# {"business_id": "Rz0KfP7YAZV_yQE8uIB0fg", "name": "El Sabor Boricua", "address": "11612 N Nebraska Ave", "city": "Tampa", "state": "FL", "postal_code": "33612", "latitude": 28.0535153, "longitude": -82.4534422, "stars": 5.0, "review_count": 6, "is_open": 0, "attributes": {"RestaurantsDelivery": "True", "RestaurantsPriceRange2": "1", "GoodForMeal": "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}", "WiFi": "u'no'", "WheelchairAccessible": "True", "GoodForKids": "True", "NoiseLevel": "u'average'", "RestaurantsGoodForGroups": "True", "Alcohol": "u'none'", "RestaurantsTableService": "True", "Caters": "True", "RestaurantsTakeOut": "True", "OutdoorSeating": "True", "Ambience": "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}", "RestaurantsReservations": "False", "BikeParking": "True"}}
#
# Document 3:
# {"business_id": "JgpnXv_0XhV3SfbfB50nxw", "name": "Joe's Pizza", "address": "2038 N Dale Mabry Hwy", "city": "Tampa", "state": "FL", "postal_code": "33607", "latitude": 27.9605142, "longitude": -82.506127, "stars": 4.0, "review_count": 35, "is_open": 0, "attributes": {"BusinessParking": "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", "GoodForKids": "True", "RestaurantsReservations": "False", "RestaurantsTakeOut": "True", "Caters": "False", "HasTV": "True", "RestaurantsPriceRange2": "1", "RestaurantsAttire": "u'casual'", "OutdoorSeating": "False", "RestaurantsDelivery": "True", "WiFi": "u'no'", "Ambience": "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}", "NoiseLevel": "u'average'", "BikeParking": "True", "Alcohol": "u'beer_and_wine'", "BusinessAcceptsCreditCards": "True", "RestaurantsGoodForGroups": "True"}}
#
# Document 4:
# {"business_id": "RK6-cJ9hj53RzOlCBmpT-g", "name": "Impasto", "address": "", "city": "Tampa", "state": "FL", "postal_code": "33611", "latitude": 27.890814, "longitude": -82.5023464, "stars": 5.0, "review_count": 5, "is_open": 1, "attributes": {"BusinessAcceptsCreditCards": "True", "RestaurantsDelivery": "False", "RestaurantsTakeOut": "True", "Caters": "True"}, "categories": "Restaurants, Italian, Food Trucks, Food", "hours": {"Monday": "0:0-0:0", "Tuesday": "0:0-0:0", "Wednesday": "0:0-0:0", "Thursday": "0:0-0:0", "Friday": "0:0-0:0", "Saturday": "0:0-0:0", "Sunday": "0:0-0:0"}}
#
# Document 5:
# {"business_id": "516L9-ZWyqVgzqjP5uW7Jg", "name": "The Corner Cafe and Deli", "address": "100 S Ashley Dr, Ste 220", "city": "Tampa", "state": "FL", "postal_code": "33602", "latitude": 27.9444574, "longitude": -82.4578244, "stars": 4.0, "review_count": 6, "is_open": 1, "attributes": {"BusinessAcceptsCreditCards": "True", "GoodForKids": "True", "Alcohol": "u'none'", "Ambience": "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}", "BusinessParking": "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}", "RestaurantsTakeOut": "True", "RestaurantsAttire": "'casual'", "OutdoorSeating": "False", "RestaurantsDelivery": "True", "Caters": "True", "HasTV": "True", "GoodForMeal": "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': False, 'breakfast': True}", "RestaurantsPriceRange2": "1", "NoiseLevel": "u'quiet'"}}
#
# Generating text with model: mistral.mistral-large-2402-v1:0
#
# Generated response:
# Based on the provided context, here are the key features of the highly-rated restaurants in Tampa:
#
# 1. Roman Forum:
#    - Cuisine type: Not specified.
#    - Ambiance: Casual.
#    - Service: Accepts credit cards, offers takeout, and caters.
#    - Price range: Moderate (2 out of 4).
#    - Standout characteristics: Outdoor seating, good for kids, and has a full bar.
#
# 2. El Sabor Boricua:
#    - Cuisine type: Not specified.
#    - Ambiance: Not specified.
#    - Service: Offers delivery, takeout, and caters.
#    - Price range: Inexpensive (1 out of 4).
#    - Standout characteristics: Wheelchair accessible, good for kids, good for groups, and outdoor seating.
#
# 3. Joe's Pizza:
#    - Cuisine type: Pizza (inferred from the name).
#    - Ambiance: Casual.
#    - Service: Accepts credit cards, offers delivery, and takeout.
#    - Price range: Inexpensive (1 out of 4).
#    - Standout characteristics: Good for kids, has TV, and offers beer and wine.
#
# 4. Impasto:
#    - Cuisine type: Italian, Food Truck (based on categories).
#    - Ambiance: Not specified.
#    - Service: Accepts credit cards, offers takeout, and caters.
#    - Price range: Not specified.
#    - Standout characteristics: Currently open.
#
# 5. The Corner Cafe and Deli:
#    - Cuisine type: Cafe and Deli (inferred from the name).
#    - Ambiance: Not specified.
#    - Service: Accepts credit cards, offers delivery, and takeout.
#    - Price range: Inexpensive (1 out of 4).
#    - Standout characteristics: Good for kids, good for lunch and breakfast, and has a quiet noise level.
# Restaurant recommendations set for Tampa
#
# Intermediate output: {'query_restaurants_RAG': {'city': 'Tampa', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}], 'events_result': 'No upcoming events found for Tampa.', 'search_result': 'We\'re your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what\'s happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!\n\nFri • 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. Jun 14. Fri • 7:00pm. Communion After Dark Presents: SITD, 00tz 00tz, and Retractor in Tampa. New World Music Hall - Tampa, FL.\n\nTue, Dec 5 •\n6:30 PM\nArmature Works\nCheck ticket price on event\nAn Evening with Omari Dillard: Soul Violinist\nFri, Dec 8 •\n8:00 PM\nCentro Asturiano de Tampa\nCheck ticket price on event\nOnline Events\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : 9th and 10th December\nSat, Dec 9 •\n12:30 PM\nGMT\nCheck ticket price on event\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 •\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n"Snow Way Out" - Weekend Pass : Today • 6:00 PM\nMacDill Park on the Riverwalk\nCheck ticket price on event\nYoga with Kodawari Studios\nTomorrow • 9:30 AM\nArmature Works\nCheck ticket price on event\nNardo Wick at Club Skye\nTomorrow • 9:00 PM\nClub Skye, East 8th Avenue, Tampa, FL, USA\nCheck ticket price on event\nSO LIT SUNDAYS\nTomorrow • 4:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nSite Navigation\nUse Eventbrite\nPlan Events\nFind Events\nConnect With Us Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchange\nCheck ticket price on event\nFemmes & Follies: 10th Anniversary Show\nSat, Dec 2 •\n7:00 PM\nThe Ritz Ybor\nCheck ticket price on event\nCigar Pxrn 6 Year Lifestyle Celebration\nSat, Dec 2 •\n1:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nArmature Works Book Club - December 5th\n Tampa & Caresgiving Soirée\nThursday • 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday • 6:30 PM\nOxford Exchang ...
#
# **************************************************
# analysis_node function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Analysis result: 1. Weather Analysis:
# Tampa is currently experiencing moderate rain with a temperature of 27.93°C, feeling like 33.02°C due to high humidity levels at 87%. The wind speed is 6.17 m/s, coming from the east-southeast direction (110°). The highest temperature for the day is expected to reach 30.1°C, while the lowest is 26.0°C. Rainfall in the past hour was 0.49mm, and cloud cover is at 40%.
#
# 2. Suggested Activities:
# Given the moderate rain and high humidity, indoor activities are recommended. Based ...
#
# Intermediate output: {'analysis': {'city': 'Tampa', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Tampa and what should I wear?"}]}, {'role': 'assistant', 'content': [{'text': '1. Weather Analysis:\nTampa is currently experiencing moderate rain with a temperature of 27.93°C, feeling like 33.02°C due to high humidity levels at 87%. The wind speed is 6.17 m/s, coming from the east-southeast direction (110°). The highest temperature for the day is expected to reach 30.1°C, while the lowest is 26.0°C. Rainfall in the past hour was 0.49mm, and cloud cover is at 40%.\n\n2. Suggested Activities:\nGiven the moderate rain and high humidity, indoor activities are recommended. Based on the events provided, here are some suggestions:\n\n- For music lovers, the "21 Savage: American Dream Tour" at MIDFLORIDA Credit Union Amphitheatre and "Communion After Dark Presents: SITD, 00tz 00tz, and Retractor" at New World Music Hall are great options.\n- Those interested in arts and culture can attend "An Evening with Omari Dillard: Soul Violinist" at Armature Works or explore the official Tampa Bay calendar of events for various festivals like Craftober, Gasparilla season, and Pride Month.\n- For online events, consider participating in "Animate Your Illustrations with Procreate Dreams: Live with Lisa Bardot", "Out in Tech | Queering the Future 2.0", or the "Career Fair: Exclusive Tech Hiring Event".\n\n3. Outfit Recommendations:\nConsidering the weather, it\'s essential to wear light, breathable clothing due to the high temperature and humidity. Opt for moisture-wicking fabrics to stay comfortable in the rain. Additionally, bring a raincoat or umbrella to protect against the moderate rain showers.\n\n4. Restaurant Recommendations:\nBased on the provided information, here are some dining options in Tampa:\n\n- Roman Forum: A casual restaurant with moderate pricing, offering outdoor seating, good for kids, and has a full bar.\n- El Sabor Boricua: An inexpensive dining option that is wheelchair accessible, good for kids, and offers outdoor seating.\n- Joe\'s Pizza: An inexpensive, casual pizza place, good for kids, offering beer and wine.\n- Impasto: An Italian food truck that accepts credit cards and offers catering services.\n- The Corner Cafe and Deli: An inexpensive cafe and deli, good for kids, and offers a quiet noise level for a relaxing dining experience.'}]}], 'events_result': 'No upcoming events found for Tampa.', 'search_result': 'We\'re your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what\'s happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!\n\nFri • 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. Jun 14. Fri • 7:00pm. Communion After Dark Presents: SITD, 00tz 00tz, and Retractor in Tampa. New World Music Hall - Tampa, FL.\n\nTue, Dec 5 •\n6:30 PM\nArmature Works\nCheck ticket price on event\nAn Evening with Omari Dillard: Soul Violinist\nFri, Dec 8 •\n8:00 PM\nCentro Asturiano de Tampa\nCheck ticket price on event\nOnline Events\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday • 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday • 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday • 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 •\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 •\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transi ...
#
# Final response from the assistant:
# [
#   {
#     "text": "1. Weather Analysis:\nTampa is currently experiencing moderate rain with a temperature of 27.93\u00b0C, feeling like 33.02\u00b0C due to high humidity levels at 87%. The wind speed is 6.17 m/s, coming from the east-southeast direction (110\u00b0). The highest temperature for the day is expected to reach 30.1\u00b0C, while the lowest is 26.0\u00b0C. Rainfall in the past hour was 0.49mm, and cloud cover is at 40%.\n\n2. Suggested Activities:\nGiven the moderate rain and high humidity, indoor activities are recommended. Based on the events provided, here are some suggestions:\n\n- For music lovers, the \"21 Savage: American Dream Tour\" at MIDFLORIDA Credit Union Amphitheatre and \"Communion After Dark Presents: SITD, 00tz 00tz, and Retractor\" at New World Music Hall are great options.\n- Those interested in arts and culture can attend \"An Evening with Omari Dillard: Soul Violinist\" at Armature Works or explore the official Tampa Bay calendar of events for various festivals like Craftober, Gasparilla season, and Pride Month.\n- For online events, consider participating in \"Animate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\", \"Out in Tech | Queering the Future 2.0\", or the \"Career Fair: Exclusive Tech Hiring Event\".\n\n3. Outfit Recommendations:\nConsidering the weather, it's essential to wear light, breathable clothing due to the high temperature and humidity. Opt for moisture-wicking fabrics to stay comfortable in the rain. Additionally, bring a raincoat or umbrella to protect against the moderate rain showers.\n\n4. Restaurant Recommendations:\nBased on the provided information, here are some dining options in Tampa:\n\n- Roman Forum: A casual restaurant with moderate pricing, offering outdoor seating, good for kids, and has a full bar.\n- El Sabor Boricua: An inexpensive dining option that is wheelchair accessible, good for kids, and offers outdoor seating.\n- Joe's Pizza: An inexpensive, casual pizza place, good for kids, offering beer and wine.\n- Impasto: An Italian food truck that accepts credit cards and offers catering services.\n- The Corner Cafe and Deli: An inexpensive cafe and deli, good for kids, and offers a quiet noise level for a relaxing dining experience."
#   }
# ]
#
# Final state from checkpointer:
# {
#   "v": 1,
#   "ts": "2024-07-06T00:29:24.518681+00:00",
#   "id": "1ef3b2ec-bc7f-6049-8005-0246072920bc",
#   "channel_values": {
#     "city": "Tampa",
#     "messages": [
#       {
#         "role": "user",
#         "content": [
#           {
#             "text": "What's happening in Tampa and what should I wear?"
#           }
#         ]
#       },
#       {
#         "role": "assistant",
#         "content": [
#           {
#             "text": "1. Weather Analysis:\nTampa is currently experiencing moderate rain with a temperature of 27.93\u00b0C, feeling like 33.02\u00b0C due to high humidity levels at 87%. The wind speed is 6.17 m/s, coming from the east-southeast direction (110\u00b0). The highest temperature for the day is expected to reach 30.1\u00b0C, while the lowest is 26.0\u00b0C. Rainfall in the past hour was 0.49mm, and cloud cover is at 40%.\n\n2. Suggested Activities:\nGiven the moderate rain and high humidity, indoor activities are recommended. Based on the events provided, here are some suggestions:\n\n- For music lovers, the \"21 Savage: American Dream Tour\" at MIDFLORIDA Credit Union Amphitheatre and \"Communion After Dark Presents: SITD, 00tz 00tz, and Retractor\" at New World Music Hall are great options.\n- Those interested in arts and culture can attend \"An Evening with Omari Dillard: Soul Violinist\" at Armature Works or explore the official Tampa Bay calendar of events for various festivals like Craftober, Gasparilla season, and Pride Month.\n- For online events, consider participating in \"Animate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\", \"Out in Tech | Queering the Future 2.0\", or the \"Career Fair: Exclusive Tech Hiring Event\".\n\n3. Outfit Recommendations:\nConsidering the weather, it's essential to wear light, breathable clothing due to the high temperature and humidity. Opt for moisture-wicking fabrics to stay comfortable in the rain. Additionally, bring a raincoat or umbrella to protect against the moderate rain showers.\n\n4. Restaurant Recommendations:\nBased on the provided information, here are some dining options in Tampa:\n\n- Roman Forum: A casual restaurant with moderate pricing, offering outdoor seating, good for kids, and has a full bar.\n- El Sabor Boricua: An inexpensive dining option that is wheelchair accessible, good for kids, and offers outdoor seating.\n- Joe's Pizza: An inexpensive, casual pizza place, good for kids, offering beer and wine.\n- Impasto: An Italian food truck that accepts credit cards and offers catering services.\n- The Corner Cafe and Deli: An inexpensive cafe and deli, good for kids, and offers a quiet noise level for a relaxing dining experience."
#           }
#         ]
#       }
#     ],
#     "events_result": "No upcoming events found for Tampa.",
#     "search_result": "We're your one-stop online destination to find and purchase tickets to local tours and attractions. Find out what's happening in Tampa this weekend or next month. Search the official Tampa Bay calendar of events for a listing of Tampa events and festivals. Explore our craft beer season (Craftober), Gasparilla season, Pride Month, and more!\n\nFri \u2022 7:00pm. 21 Savage: American Dream Tour. MIDFLORIDA Credit Union Amphitheatre at the FL State Fairgrounds - Tampa, FL. Add-Ons Available. See Tickets. Jun 14. Fri \u2022 7:00pm. Communion After Dark Presents: SITD, 00tz 00tz, and Retractor in Tampa. New World Music Hall - Tampa, FL.\n\nTue, Dec 5 \u2022\n6:30 PM\nArmature Works\nCheck ticket price on event\nAn Evening with Omari Dillard: Soul Violinist\nFri, Dec 8 \u2022\n8:00 PM\nCentro Asturiano de Tampa\nCheck ticket price on event\nOnline Events\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday \u2022 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday \u2022 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday \u2022 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 \u2022\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 \u2022\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 \u2022\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n\"Snow Way Out\" - Weekend Pass : 9th and 10th December\nSat, Dec 9 \u2022\n12:30 PM\nGMT\nCheck ticket price on event\nAnimate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\nMonday \u2022 1:00 PM EST\nCheck ticket price on event\nOut in Tech | Queering the Future 2.0\nWednesday \u2022 3:00 PM EST\nCheck ticket price on event\nCareer Fair: Exclusive Tech Hiring Event-New Tickets Available\nFriday \u2022 9:00 AM PST\nCheck ticket price on event\nModern Investor Summit 2023\nCheck ticket price on event\nHow to Build, Evaluate, and Iterate on LLM Agents\nTue, Dec 5 \u2022\n10:00 AM\nPST\nCheck ticket price on event\nOffice of Manufacturing and Energy Supply Chains (MESC) Information Session\nThu, Dec 7 \u2022\n1:00 PM\nEST\nCheck ticket price on event\nA Person-Centered Approach to Transitions in Caregiving with Teepa Snow\nFri, Dec 8 \u2022\n10:00 AM\nEST\nCheck ticket price on event\nSorted Live\n\"Snow Way Out\" - Weekend Pass : Today \u2022 6:00 PM\nMacDill Park on the Riverwalk\nCheck ticket price on event\nYoga with Kodawari Studios\nTomorrow \u2022 9:30 AM\nArmature Works\nCheck ticket price on event\nNardo Wick at Club Skye\nTomorrow \u2022 9:00 PM\nClub Skye, East 8th Avenue, Tampa, FL, USA\nCheck ticket price on event\nSO LIT SUNDAYS\nTomorrow \u2022 4:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nSite Navigation\nUse Eventbrite\nPlan Events\nFind Events\nConnect With Us Tampa & Caresgiving Soir\u00e9e\nThursday \u2022 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday \u2022 6:30 PM\nOxford Exchange\nCheck ticket price on event\nFemmes & Follies: 10th Anniversary Show\nSat, Dec 2 \u2022\n7:00 PM\nThe Ritz Ybor\nCheck ticket price on event\nCigar Pxrn 6 Year Lifestyle Celebration\nSat, Dec 2 \u2022\n1:00 PM\nLIT Cigar & Martini Lounge, North Franklin Street, Tampa, FL, USA\nCheck ticket price on event\nArmature Works Book Club - December 5th\n Tampa & Caresgiving Soir\u00e9e\nThursday \u2022 5:00 PM\nHyde House Black Box Auditorium\nCheck ticket price on event\nOE Holiday Gift Bazaar | Shop & Champagne\nThursday \u2022 6:30 PM\nOxford Exchange\nCheck ticket price on event\nFemmes & Follies: 10th Anniversary Show\nSat,  ...
#     "weather_info": {
#       "city": "Tampa",
#       "weather": "In Tampa, the current weather is as follows:\nDetailed status: moderate rain\nWind speed: 6.17 m/s, direction: 110\u00b0\nHumidity: 87%\nTemperature: \n  - Current: 27.93\u00b0C\n  - High: 30.1\u00b0C\n  - Low: 26.0\u00b0C\n  - Feels like: 33.02\u00b0C\nRain: {'1h': 0.49}\nHeat index: None\nCloud cover: 40%"
#     },
#     "analysis_result": "1. Weather Analysis:\nTampa is currently experiencing moderate rain with a temperature of 27.93\u00b0C, feeling like 33.02\u00b0C due to high humidity levels at 87%. The wind speed is 6.17 m/s, coming from the east-southeast direction (110\u00b0). The highest temperature for the day is expected to reach 30.1\u00b0C, while the lowest is 26.0\u00b0C. Rainfall in the past hour was 0.49mm, and cloud cover is at 40%.\n\n2. Suggested Activities:\nGiven the moderate rain and high humidity, indoor activities are recommended. Based on the events provided, here are some suggestions:\n\n- For music lovers, the \"21 Savage: American Dream Tour\" at MIDFLORIDA Credit Union Amphitheatre and \"Communion After Dark Presents: SITD, 00tz 00tz, and Retractor\" at New World Music Hall are great options.\n- Those interested in arts and culture can attend \"An Evening with Omari Dillard: Soul Violinist\" at Armature Works or explore the official Tampa Bay calendar of events for various festivals like Craftober, Gasparilla season, and Pride Month.\n- For online events, consider participating in \"Animate Your Illustrations with Procreate Dreams: Live with Lisa Bardot\", \"Out in Tech | Queering the Future 2.0\", or the \"Career Fair: Exclusive Tech Hiring Event\".\n\n3. Outfit Recommendations:\nConsidering the weather, it's essential to wear light, breathable clothing due to the high temperature and humidity. Opt for moisture-wicking fabrics to stay comfortable in the rain. Additionally, bring a raincoat or umbrella to protect against the moderate rain showers.\n\n4. Restaurant Recommendations:\nBased on the provided information, here are some dining options in Tampa:\n\n- Roman Forum: A casual restaurant with moderate pricing, offering outdoor seating, good for kids, and has a full bar.\n- El Sabor Boricua: An inexpensive dining option that is wheelchair accessible, good for kids, and offers outdoor seating.\n- Joe's Pizza: An inexpensive, casual pizza place, good for kids, offering beer and wine.\n- Impasto: An Italian food truck that accepts credit cards and offers catering services.\n- The Corner Cafe and Deli: An inexpensive cafe and deli, good for kids, and offers a quiet noise level for a relaxing dining experience.",
#     "restaurant_recommendations": "Based on the provided context, here are the key features of the highly-rated restaurants in Tampa:\n\n1. Roman Forum:\n   - Cuisine type: Not specified.\n   - Ambiance: Casual.\n   - Service: Accepts credit cards, offers takeout, and caters.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Outdoor seating, good for kids, and has a full bar.\n\n2. El Sabor Boricua:\n   - Cuisine type: Not specified.\n   - Ambiance: Not specified.\n   - Service: Offers delivery, takeout, and caters.\n   - Price range: Inexpensive (1 out of 4).\n   - Standout characteristics: Wheelchair accessible, good for kids, good for groups, and outdoor seating.\n\n3. Joe's Pizza:\n   - Cuisine type: Pizza (inferred from the name).\n   - Ambiance: Casual.\n   - Service: Accepts credit cards, offers delivery, and takeout.\n   - Price range: Inexpensive (1 out of 4).\n   - Standout characteristics: Good for kids, has TV, and offers beer and wine.\n\n4. Impasto:\n   - Cuisine type: Italian, Food Truck (based on categories).\n   - Ambiance: Not specified.\n   - Service: Accepts credit cards, offers takeout, and caters.\n   - Price range: Not specified.\n   - Standout characteristics: Currently open.\n\n5. The Corner Cafe and Deli:\n   - Cuisine type: Cafe and Deli (inferred from the name).\n   - Ambiance: Not specified.\n   - Service: Accepts credit cards, offers delivery, and takeout.\n   - Price range: Inexpensive (1 out of 4).\n   - Standout characteristics: Good for kids, good for lunch and breakfast, and has a quiet noise level.",
#     "analysis": "analysis"
#   },
#   "channel_versions": {
#     "__start__": 2,
#     "city": 7,
#     "messages": 7,
#     "events_result": 7,
#     "search_result": 7,
#     "weather_info": 7,
#     "analysis_result": 7,
#     "restaurant_recommendations": 7,
#     "start:eventsDB_tool": 3,
#     "eventsDB_tool": 4,
#     "branch:eventsDB_tool:route_events:search_tool": 4,
#     "search_tool": 5,
#     "weather_tool": 6,
#     "query_restaurants_RAG": 7,
#     "analysis": 7
#   },
#   "versions_seen": {
#     "__start__": {
#       "__start__": 1
#     },
#     "eventsDB_tool": {
#       "start:eventsDB_tool": 2
#     },
#     "search_tool": {
#       "branch:eventsDB_tool:route_events:search_tool": 3
#     },
#     "weather_tool": {
#       "search_tool": 4
#     },
#     "query_restaurants_RAG": {
#       "weather_tool": 5
#     },
#     "analysis": {
#       "query_restaurants_RAG": 6
#     }
#   },
#   "pending_sends": []
# }

# %% [markdown]
# ### Example 2: Philadelphia, Pennsylvania

# %%
if __name__ == "__main__":
    city = "Philadelphia"
    print(f"Starting script execution for city: {city}")
    main(city)
# Out:
# Starting script execution for city: Philadelphia
# Starting main execution for city: Philadelphia
# Workflow compiled successfully
# Graph built successfully
# Starting to stream events
#
# **************************************************
# eventsDB_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
#                    event_name  event_date  \
# 0    Philadelphia Flower Show  2024-03-02
# 1        Wawa Welcome America  2024-06-28
# 2  Philadelphia Film Festival  2024-10-17
#
#                                          description
# 0  The world's largest indoor flower show, featur...
# 1  A week-long festival celebrating Independence ...
# 2  An annual film festival showcasing independent...
# Events set to: Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.
# Wawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.
# Philadelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.
# Routing events. Current state: city='Philadelphia' messages=[{'role': 'user', 'content': [{'text': "What's happening in Philadelphia and what should I wear?"}]}] events_result="Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films." search_result='' weather_info={} analysis_result='' restaurant_recommendations=''
# Events content: 'Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.
# Wawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.
# Philadelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.'
# Events found in local DB. Routing to weather_tool.
#
# Intermediate output: {'eventsDB_tool': {'city': 'Philadelphia', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Philadelphia and what should I wear?"}]}], 'events_result': "Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.", 'search_result': '', 'weather_info': {}, 'analysis_result': '', 'restaurant_recommendations': ''}}
#
# **************************************************
# weather_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Weather info set to: {'city': 'Philadelphia', 'weather': 'In Philadelphia, the current weather is as follows:\nDetailed status: scattered clouds\nWind speed: 3.6 m/s, direction: 180°\nHumidity: 69%\nTemperature: \n  - Current: 31.38°C\n  - High: 32.64°C\n  - Low: 29.32°C\n  - Feels like: 38.31°C\nRain: {}\nHeat index: None\nCloud cover: 40%'}
#
# Intermediate output: {'weather_tool': {'city': 'Philadelphia', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Philadelphia and what should I wear?"}]}], 'events_result': "Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.", 'search_result': '', 'weather_info': {'city': 'Philadelphia', 'weather': 'In Philadelphia, the current weather is as follows:\nDetailed status: scattered clouds\nWind speed: 3.6 m/s, direction: 180°\nHumidity: 69%\nTemperature: \n  - Current: 31.38°C\n  - High: 32.64°C\n  - Low: 29.32°C\n  - Feels like: 38.31°C\nRain: {}\nHeat index: None\nCloud cover: 40%'}, 'analysis_result': '', 'restaurant_recommendations': ''}}
#
# **************************************************
# query_restaurants_node function called
# **************************************************
#
# Performing query: Find restaurants with 4 stars or higher ratings in Philadelphia and describe their key features
#
# Top 5 relevant documents for high-rated restaurants in Philadelphia:
#
# Document 1:
# {"business_id": "0CEUpFtaKhxbmrbSdP9MUQ", "name": "Acadia", "address": "824 S 8th St", "city": "Philadelphia", "state": "PA", "postal_code": "19147", "latitude": 39.9389483, "longitude": -75.1564078, "stars": 4.0, "review_count": 79, "is_open": 0, "attributes": {"Caters": "True", "DogsAllowed": "True", "RestaurantsPriceRange2": "2", "RestaurantsTakeOut": "True", "RestaurantsReservations": "True", "GoodForMeal": "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}", "BusinessParking": "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", "WiFi": "u'free'", "BikeParking": "True", "GoodForDancing": "False", "ByAppointmentOnly": "False", "Music": "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}", "CoatCheck": "False"}}
#
# Document 2:
# {"business_id": "ROeacJQwBeh05Rqg7F6TCg", "name": "BAP", "address": "1224 South St", "city": "Philadelphia", "state": "PA", "postal_code": "19147", "latitude": 39.943223, "longitude": -75.162568, "stars": 4.5, "review_count": 205, "is_open": 1, "attributes": {"NoiseLevel": "u'quiet'", "GoodForMeal": "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}", "RestaurantsGoodForGroups": "False", "RestaurantsTableService": "True", "WiFi": "u'no'", "GoodForKids": "True", "Alcohol": "u'none'", "RestaurantsPriceRange2": "1", "RestaurantsAttire": "u'casual'", "BikeParking": "True", "BusinessParking": "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", "Caters": "True", "RestaurantsReservations": "False", "HasTV": "True", "BusinessAcceptsCreditCards": "True", "OutdoorSeating": "None"}}
#
# Document 3:
# {"business_id": "dChRGpit9fM_kZK5pafNyA", "name": "The Love", "address": "130 S 18th St", "city": "Philadelphia", "state": "PA", "postal_code": "19103", "latitude": 39.9506555, "longitude": -75.1708991, "stars": 4.0, "review_count": 618, "is_open": 1, "attributes": {"BusinessAcceptsCreditCards": "True", "RestaurantsReservations": "True", "HasTV": "False", "GoodForMeal": "{'dessert': True, 'latenight': None, 'lunch': True, 'dinner': True, 'brunch': True, 'breakfast': None}", "RestaurantsGoodForGroups": "True", "BusinessParking": "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", "RestaurantsAttire": "u'casual'", "NoiseLevel": "u'average'", "Ambience": "{'touristy': False, 'hipster': False, 'romantic': True, 'divey': False, 'intimate': True, 'trendy': True, 'upscale': False, 'classy': True, 'casual': False}", "Caters": "False", "DogsAllowed": "False", "RestaurantsTableService": "True", "Alcohol": "u'full_bar'", "BikeParking": "True"}}
#
# Document 4:
# {"business_id": "bqmX882_6AxVA_uHEQ70sQ", "name": "Shanghai Station", "address": "4002 Spruce St", "city": "Philadelphia", "state": "PA", "postal_code": "19104", "latitude": 39.9516153765, "longitude": -75.2033457223, "stars": 4.0, "review_count": 46, "is_open": 0, "attributes": {"Caters": "False", "BikeParking": "False", "RestaurantsAttire": "'casual'", "BusinessAcceptsCreditCards": "True", "DogsAllowed": "False", "RestaurantsTakeOut": "True", "BusinessAcceptsBitcoin": "False", "BusinessParking": "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", "Smoking": "u'no'", "WiFi": "u'free'", "CoatCheck": "False", "HasTV": "True", "WheelchairAccessible": "False", "GoodForKids": "True", "RestaurantsTableService": "True", "GoodForMeal": "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}", "Music": "{'karaoke': True}", "RestaurantsPriceRange2": "2", "RestaurantsReservations": "True"}}
#
# Document 5:
# {"business_id": "QdN72BWoyFypdGJhhI5r7g", "name": "Bar One", "address": "767 S 9th St", "city": "Philadelphia", "state": "PA", "postal_code": "19147", "latitude": 39.9398245705, "longitude": -75.1574465632, "stars": 4.0, "review_count": 65, "is_open": 0, "attributes": {"Smoking": "u'no'", "NoiseLevel": "u'average'", "Caters": "False", "WiFi": "u'free'", "RestaurantsGoodForGroups": "True", "Music": "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}", "OutdoorSeating": "False", "RestaurantsTableService": "True", "RestaurantsAttire": "'casual'", "Ambience": "{'touristy': False, 'hipster': True, 'romantic': None, 'divey': False, 'intimate': False, 'trendy': None, 'upscale': False, 'classy': None, 'casual': True}", "RestaurantsReservations": "False", "RestaurantsTakeOut": "True", "GoodForDancing": "False", "RestaurantsPriceRange2": "2"}}
#
# Generating text with model: mistral.mistral-large-2402-v1:0
#
# Generated response:
# Based on the provided context, here are the key features of the highly-rated restaurants in Philadelphia:
#
# 1. **Acadia**
#    - Cuisine type: Not mentioned.
#    - Ambiance: Not mentioned.
#    - Service: The restaurant offers takeout, reservations, and caters, suggesting a customer-focused service.
#    - Price range: Moderate (2 out of 4).
#    - Standout characteristics: Dogs are allowed, and there's free WiFi and bike parking available.
#
# 2. **BAP**
#    - Cuisine type: Not mentioned.
#    - Ambiance: Quiet and casual.
#    - Service: The restaurant offers table service and accepts credit cards. It does not accept reservations.
#    - Price range: Inexpensive (1 out of 4).
#    - Standout characteristics: Good for kids, has TV, and offers free bike parking. No alcohol is served.
#
# 3. **The Love**
#    - Cuisine type: Not mentioned.
#    - Ambiance: Romantic, intimate, trendy, and classy. The noise level is average.
#    - Service: The restaurant accepts reservations, offers table service, and accepts credit cards.
#    - Price range: Not mentioned.
#    - Standout characteristics: Good for groups and various meals (dessert, lunch, dinner, brunch). Full bar available.
#
# 4. **Shanghai Station**
#    - Cuisine type: Not mentioned, but the name suggests it might serve Chinese food.
#    - Ambiance: Casual.
#    - Service: The restaurant offers takeout, accepts reservations, offers table service, and accepts credit cards.
#    - Price range: Moderate (2 out of 4).
#    - Standout characteristics: Good for kids, has TV, offers free WiFi, and allows karaoke.
#
# 5. **Bar One**
#    - Cuisine type: Not mentioned.
#    - Ambiance: Casual and hipster. The noise level is average.
#    - Service: The restaurant offers takeout, accepts credit cards, and offers free WiFi. It does not accept reservations.
#    - Price range: Moderate (2 out of 4).
#    - Standout characteristics: Good for groups, but outdoor seating is not available.
# Restaurant recommendations set for Philadelphia
#
# Intermediate output: {'query_restaurants_RAG': {'city': 'Philadelphia', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Philadelphia and what should I wear?"}]}], 'events_result': "Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.", 'search_result': '', 'weather_info': {'city': 'Philadelphia', 'weather': 'In Philadelphia, the current weather is as follows:\nDetailed status: scattered clouds\nWind speed: 3.6 m/s, direction: 180°\nHumidity: 69%\nTemperature: \n  - Current: 31.38°C\n  - High: 32.64°C\n  - Low: 29.32°C\n  - Feels like: 38.31°C\nRain: {}\nHeat index: None\nCloud cover: 40%'}, 'analysis_result': '', 'restaurant_recommendations': "Based on the provided context, here are the key features of the highly-rated restaurants in Philadelphia:\n\n1. **Acadia**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Not mentioned.\n   - Service: The restaurant offers takeout, reservations, and caters, suggesting a customer-focused service.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Dogs are allowed, and there's free WiFi and bike parking available.\n\n2. **BAP**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Quiet and casual.\n   - Service: The restaurant offers table service and accepts credit cards. It does not accept reservations.\n   - Price range: Inexpensive (1 out of 4).\n   - Standout characteristics: Good for kids, has TV, and offers free bike parking. No alcohol is served.\n\n3. **The Love**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Romantic, intimate, trendy, and classy. The noise level is average.\n   - Service: The restaurant accepts reservations, offers table service, and accepts credit cards.\n   - Price range: Not mentioned.\n   - Standout characteristics: Good for groups and various meals (dessert, lunch, dinner, brunch). Full bar available.\n\n4. **Shanghai Station**\n   - Cuisine type: Not mentioned, but the name suggests it might serve Chinese food.\n   - Ambiance: Casual.\n   - Service: The restaurant offers takeout, accepts reservations, offers table service, and accepts credit cards.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Good for kids, has TV, offers free WiFi, and allows karaoke.\n\n5. **Bar One**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Casual and hipster. The noise level is average.\n   - Service: The restaurant offers takeout, accepts credit cards, and offers free WiFi. It does not accept reservations.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Good for groups, but outdoor seating is not available."}}
#
# **************************************************
# analysis_node function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Analysis result: 1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38°C, feeling like 38.31°C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.
#
# 2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elabora...
#
# Intermediate output: {'analysis': {'city': 'Philadelphia', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in Philadelphia and what should I wear?"}]}, {'role': 'assistant', 'content': [{'text': "1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38°C, feeling like 38.31°C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.\n\n2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elaborate garden displays. However, as this event is not imminent, consider visiting a local park or garden to enjoy the current warm weather. The Wawa Welcome America festival in June would also be a good fit for the current weather, with outdoor concerts, fireworks, and historical reenactments. The Philadelphia Film Festival in October might be too warm for some, but theaters are typically air-conditioned.\n\n3. Outfit Recommendations: Considering the high temperature and humidity, lightweight, breathable clothing is recommended. Opt for shorts, t-shirts, sundresses, or light linen pants. Don't forget sunglasses, a hat, and sunscreen to protect from the sun. Stay hydrated throughout the day.\n\n4. Restaurant Recommendations:\n   - **Acadia**: A moderately-priced restaurant that's dog-friendly and offers free WiFi and bike parking. Ideal for a casual meal.\n   - **BAP**: An inexpensive option with a quiet, casual ambiance. Good for families with kids and those who prefer a non-alcoholic setting.\n   - **The Love**: A romantic, intimate, and trendy restaurant suitable for various meals. The full bar makes it a great choice for a night out.\n   - **Shanghai Station**: A moderately-priced restaurant that's good for families. The availability of karaoke adds an element of fun.\n   - **Bar One**: A hipster spot that's good for groups. It's a moderately-priced option for a casual meal or drinks."}]}], 'events_result': "Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.", 'search_result': '', 'weather_info': {'city': 'Philadelphia', 'weather': 'In Philadelphia, the current weather is as follows:\nDetailed status: scattered clouds\nWind speed: 3.6 m/s, direction: 180°\nHumidity: 69%\nTemperature: \n  - Current: 31.38°C\n  - High: 32.64°C\n  - Low: 29.32°C\n  - Feels like: 38.31°C\nRain: {}\nHeat index: None\nCloud cover: 40%'}, 'analysis_result': "1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38°C, feeling like 38.31°C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.\n\n2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elaborate garden displays. However, as this event is not imminent, consider visiting a local park or garden to enjoy the current warm weather. The Wawa Welcome America festival in June would also be a good fit for the current weather, with outdoor concerts, fireworks, and historical reenactments. The Philadelphia Film Festival in October might be too warm for some, but theaters are typically air-conditioned.\n\n3. Outfit Recommendations: Considering the high temperature and humidity, lightweight, breathable clothing is recommended. Opt for shorts, t-shirts, sundresses, or light linen pants. ...
#
# Final response from the assistant:
# [
#   {
#     "text": "1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38\u00b0C, feeling like 38.31\u00b0C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.\n\n2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elaborate garden displays. However, as this event is not imminent, consider visiting a local park or garden to enjoy the current warm weather. The Wawa Welcome America festival in June would also be a good fit for the current weather, with outdoor concerts, fireworks, and historical reenactments. The Philadelphia Film Festival in October might be too warm for some, but theaters are typically air-conditioned.\n\n3. Outfit Recommendations: Considering the high temperature and humidity, lightweight, breathable clothing is recommended. Opt for shorts, t-shirts, sundresses, or light linen pants. Don't forget sunglasses, a hat, and sunscreen to protect from the sun. Stay hydrated throughout the day.\n\n4. Restaurant Recommendations:\n   - **Acadia**: A moderately-priced restaurant that's dog-friendly and offers free WiFi and bike parking. Ideal for a casual meal.\n   - **BAP**: An inexpensive option with a quiet, casual ambiance. Good for families with kids and those who prefer a non-alcoholic setting.\n   - **The Love**: A romantic, intimate, and trendy restaurant suitable for various meals. The full bar makes it a great choice for a night out.\n   - **Shanghai Station**: A moderately-priced restaurant that's good for families. The availability of karaoke adds an element of fun.\n   - **Bar One**: A hipster spot that's good for groups. It's a moderately-priced option for a casual meal or drinks."
#   }
# ]
#
# Final state from checkpointer:
# {
#   "v": 1,
#   "ts": "2024-07-06T00:29:59.240856+00:00",
#   "id": "1ef3b2ee-07a1-6f5f-8004-da1ccefb1315",
#   "channel_values": {
#     "city": "Philadelphia",
#     "messages": [
#       {
#         "role": "user",
#         "content": [
#           {
#             "text": "What's happening in Philadelphia and what should I wear?"
#           }
#         ]
#       },
#       {
#         "role": "assistant",
#         "content": [
#           {
#             "text": "1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38\u00b0C, feeling like 38.31\u00b0C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.\n\n2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elaborate garden displays. However, as this event is not imminent, consider visiting a local park or garden to enjoy the current warm weather. The Wawa Welcome America festival in June would also be a good fit for the current weather, with outdoor concerts, fireworks, and historical reenactments. The Philadelphia Film Festival in October might be too warm for some, but theaters are typically air-conditioned.\n\n3. Outfit Recommendations: Considering the high temperature and humidity, lightweight, breathable clothing is recommended. Opt for shorts, t-shirts, sundresses, or light linen pants. Don't forget sunglasses, a hat, and sunscreen to protect from the sun. Stay hydrated throughout the day.\n\n4. Restaurant Recommendations:\n   - **Acadia**: A moderately-priced restaurant that's dog-friendly and offers free WiFi and bike parking. Ideal for a casual meal.\n   - **BAP**: An inexpensive option with a quiet, casual ambiance. Good for families with kids and those who prefer a non-alcoholic setting.\n   - **The Love**: A romantic, intimate, and trendy restaurant suitable for various meals. The full bar makes it a great choice for a night out.\n   - **Shanghai Station**: A moderately-priced restaurant that's good for families. The availability of karaoke adds an element of fun.\n   - **Bar One**: A hipster spot that's good for groups. It's a moderately-priced option for a casual meal or drinks."
#           }
#         ]
#       }
#     ],
#     "events_result": "Philadelphia Flower Show on 2024-03-02: The world's largest indoor flower show, featuring elaborate garden displays.\nWawa Welcome America on 2024-06-28: A week-long festival celebrating Independence Day with concerts, fireworks, and historical reenactments.\nPhiladelphia Film Festival on 2024-10-17: An annual film festival showcasing independent and international films.",
#     "search_result": "",
#     "weather_info": {
#       "city": "Philadelphia",
#       "weather": "In Philadelphia, the current weather is as follows:\nDetailed status: scattered clouds\nWind speed: 3.6 m/s, direction: 180\u00b0\nHumidity: 69%\nTemperature: \n  - Current: 31.38\u00b0C\n  - High: 32.64\u00b0C\n  - Low: 29.32\u00b0C\n  - Feels like: 38.31\u00b0C\nRain: {}\nHeat index: None\nCloud cover: 40%"
#     },
#     "analysis_result": "1. Weather Analysis: The current weather in Philadelphia is scattered clouds with a temperature of 31.38\u00b0C, feeling like 38.31\u00b0C due to humidity at 69%. The wind speed is 3.6 m/s from the south. It's a hot day, but the cloud cover provides some relief from direct sunlight.\n\n2. Suggested Activities: Given the warm weather, outdoor activities are suitable. The Philadelphia Flower Show on March 2nd would be a great choice as it's an indoor event, providing a comfortable environment to enjoy elaborate garden displays. However, as this event is not imminent, consider visiting a local park or garden to enjoy the current warm weather. The Wawa Welcome America festival in June would also be a good fit for the current weather, with outdoor concerts, fireworks, and historical reenactments. The Philadelphia Film Festival in October might be too warm for some, but theaters are typically air-conditioned.\n\n3. Outfit Recommendations: Considering the high temperature and humidity, lightweight, breathable clothing is recommended. Opt for shorts, t-shirts, sundresses, or light linen pants. Don't forget sunglasses, a hat, and sunscreen to protect from the sun. Stay hydrated throughout the day.\n\n4. Restaurant Recommendations:\n   - **Acadia**: A moderately-priced restaurant that's dog-friendly and offers free WiFi and bike parking. Ideal for a casual meal.\n   - **BAP**: An inexpensive option with a quiet, casual ambiance. Good for families with kids and those who prefer a non-alcoholic setting.\n   - **The Love**: A romantic, intimate, and trendy restaurant suitable for various meals. The full bar makes it a great choice for a night out.\n   - **Shanghai Station**: A moderately-priced restaurant that's good for families. The availability of karaoke adds an element of fun.\n   - **Bar One**: A hipster spot that's good for groups. It's a moderately-priced option for a casual meal or drinks.",
#     "restaurant_recommendations": "Based on the provided context, here are the key features of the highly-rated restaurants in Philadelphia:\n\n1. **Acadia**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Not mentioned.\n   - Service: The restaurant offers takeout, reservations, and caters, suggesting a customer-focused service.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Dogs are allowed, and there's free WiFi and bike parking available.\n\n2. **BAP**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Quiet and casual.\n   - Service: The restaurant offers table service and accepts credit cards. It does not accept reservations.\n   - Price range: Inexpensive (1 out of 4).\n   - Standout characteristics: Good for kids, has TV, and offers free bike parking. No alcohol is served.\n\n3. **The Love**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Romantic, intimate, trendy, and classy. The noise level is average.\n   - Service: The restaurant accepts reservations, offers table service, and accepts credit cards.\n   - Price range: Not mentioned.\n   - Standout characteristics: Good for groups and various meals (dessert, lunch, dinner, brunch). Full bar available.\n\n4. **Shanghai Station**\n   - Cuisine type: Not mentioned, but the name suggests it might serve Chinese food.\n   - Ambiance: Casual.\n   - Service: The restaurant offers takeout, accepts reservations, offers table service, and accepts credit cards.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Good for kids, has TV, offers free WiFi, and allows karaoke.\n\n5. **Bar One**\n   - Cuisine type: Not mentioned.\n   - Ambiance: Casual and hipster. The noise level is average.\n   - Service: The restaurant offers takeout, accepts credit cards, and offers free WiFi. It does not accept reservations.\n   - Price range: Moderate (2 out of 4).\n   - Standout characteristics: Good for groups, but outdoor seating is not available.",
#     "analysis": "analysis"
#   },
#   "channel_versions": {
#     "__start__": 2,
#     "city": 6,
#     "messages": 6,
#     "events_result": 6,
#     "search_result": 6,
#     "weather_info": 6,
#     "analysis_result": 6,
#     "restaurant_recommendations": 6,
#     "start:eventsDB_tool": 3,
#     "eventsDB_tool": 4,
#     "branch:eventsDB_tool:route_events:weather_tool": 4,
#     "weather_tool": 5,
#     "query_restaurants_RAG": 6,
#     "analysis": 6
#   },
#   "versions_seen": {
#     "__start__": {
#       "__start__": 1
#     },
#     "eventsDB_tool": {
#       "start:eventsDB_tool": 2
#     },
#     "search_tool": {},
#     "weather_tool": {
#       "branch:eventsDB_tool:route_events:weather_tool": 3
#     },
#     "query_restaurants_RAG": {
#       "weather_tool": 4
#     },
#     "analysis": {
#       "query_restaurants_RAG": 5
#     }
#   },
#   "pending_sends": []
# }

# %% [markdown]
# ### Example 3: New York

# %%
if __name__ == "__main__":
    city = "New York"
    print(f"Starting script execution for city: {city}")
    main(city)
# Out:
# Starting script execution for city: New York
# Starting main execution for city: New York
# Workflow compiled successfully
# Graph built successfully
# Starting to stream events
#
# **************************************************
# eventsDB_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
#                        event_name  event_date  \
# 0           Tribeca Film Festival  2024-06-07
# 1           New York Fashion Week  2024-09-05
# 2  Macy's Thanksgiving Day Parade  2024-11-28
#
#                                          description
# 0     An annual film festival in Tribeca, Manhattan.
# 1            A semi-annual series of fashion events.
# 2  An annual parade presented by Macy's on Thanks...
# Events set to: Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.
# New York Fashion Week on 2024-09-05: A semi-annual series of fashion events.
# Macy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.
# Routing events. Current state: city='New York' messages=[{'role': 'user', 'content': [{'text': "What's happening in New York and what should I wear?"}]}] events_result="Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day." search_result='' weather_info={} analysis_result='' restaurant_recommendations=''
# Events content: 'Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.
# New York Fashion Week on 2024-09-05: A semi-annual series of fashion events.
# Macy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.'
# Events found in local DB. Routing to weather_tool.
#
# Intermediate output: {'eventsDB_tool': {'city': 'New York', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in New York and what should I wear?"}]}], 'events_result': "Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.", 'search_result': '', 'weather_info': {}, 'analysis_result': '', 'restaurant_recommendations': ''}}
#
# **************************************************
# weather_tool function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Weather info set to: {'city': 'New York', 'weather': 'In New York, the current weather is as follows:\nDetailed status: mist\nWind speed: 5.14 m/s, direction: 200°\nHumidity: 85%\nTemperature: \n  - Current: 25.12°C\n  - High: 26.98°C\n  - Low: 23.86°C\n  - Feels like: 25.91°C\nRain: {}\nHeat index: None\nCloud cover: 100%'}
#
# Intermediate output: {'weather_tool': {'city': 'New York', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in New York and what should I wear?"}]}], 'events_result': "Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.", 'search_result': '', 'weather_info': {'city': 'New York', 'weather': 'In New York, the current weather is as follows:\nDetailed status: mist\nWind speed: 5.14 m/s, direction: 200°\nHumidity: 85%\nTemperature: \n  - Current: 25.12°C\n  - High: 26.98°C\n  - Low: 23.86°C\n  - Feels like: 25.91°C\nRain: {}\nHeat index: None\nCloud cover: 100%'}, 'analysis_result': '', 'restaurant_recommendations': ''}}
#
# **************************************************
# query_restaurants_node function called
# **************************************************
#
# Performing query: Find restaurants with 4 stars or higher ratings in New York and describe their key features
# No high-rated restaurants found in New York.
#
# Generating text with model: mistral.mistral-large-2402-v1:0
#
# Generated response:
# I'm sorry, but I couldn't find any information about highly-rated restaurants in New York.
# Restaurant recommendations set for New York
#
# Intermediate output: {'query_restaurants_RAG': {'city': 'New York', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in New York and what should I wear?"}]}], 'events_result': "Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.", 'search_result': '', 'weather_info': {'city': 'New York', 'weather': 'In New York, the current weather is as follows:\nDetailed status: mist\nWind speed: 5.14 m/s, direction: 200°\nHumidity: 85%\nTemperature: \n  - Current: 25.12°C\n  - High: 26.98°C\n  - Low: 23.86°C\n  - Feels like: 25.91°C\nRain: {}\nHeat index: None\nCloud cover: 100%'}, 'analysis_result': '', 'restaurant_recommendations': "I'm sorry, but I couldn't find any information about highly-rated restaurants in New York."}}
#
# **************************************************
# analysis_node function called
# **************************************************
#
# Generating text with model: mistral.mistral-large-2402-v1:0
# Analysis result: 1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200°). The current temperature is 25.12°C, feeling like 25.91°C, with a high of 26.98°C and a low of 23.86°C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.
#
# 2. Suggested Activities: Given the misty and overcast weather, outdoo...
#
# Intermediate output: {'analysis': {'city': 'New York', 'messages': [{'role': 'user', 'content': [{'text': "What's happening in New York and what should I wear?"}]}, {'role': 'assistant', 'content': [{'text': "1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200°). The current temperature is 25.12°C, feeling like 25.91°C, with a high of 26.98°C and a low of 23.86°C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.\n\n2. Suggested Activities: Given the misty and overcast weather, outdoor activities may not be ideal, but the temperature is still quite comfortable for exploring the city. You can consider attending indoor events like the Tribeca Film Festival on June 7th, 2024, where you can enjoy a variety of films from different genres. If you're visiting in September, New York Fashion Week on September 5th, 2024, would be an excellent choice for fashion enthusiasts. For those planning a trip around Thanksgiving, the Macy's Thanksgiving Day Parade on November 28th, 2024, is a must-see event, although you should dress warmly and be prepared for potential rain or colder temperatures during that time of year.\n\n3. Outfit Recommendations: Considering the current weather, opt for a light, water-resistant jacket or a sweater to stay comfortable in the misty conditions. Pair it with lightweight pants or jeans and comfortable walking shoes. Since the temperature is mild, layering is key to easily adapt to any changes in weather throughout the day. Don't forget an umbrella to stay dry in case of light rain.\n\n4. Restaurant Recommendations: Unfortunately, the provided information does not include any highly-rated restaurants in New York. However, New York City is known for its diverse culinary scene, offering a wide range of dining options to suit different tastes and budgets. Some popular categories include pizza, bagels, fine dining, and international cuisine. I recommend searching for specific recommendations based on your preferences and location within the city."}]}], 'events_result': "Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.", 'search_result': '', 'weather_info': {'city': 'New York', 'weather': 'In New York, the current weather is as follows:\nDetailed status: mist\nWind speed: 5.14 m/s, direction: 200°\nHumidity: 85%\nTemperature: \n  - Current: 25.12°C\n  - High: 26.98°C\n  - Low: 23.86°C\n  - Feels like: 25.91°C\nRain: {}\nHeat index: None\nCloud cover: 100%'}, 'analysis_result': "1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200°). The current temperature is 25.12°C, feeling like 25.91°C, with a high of 26.98°C and a low of 23.86°C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.\n\n2. Suggested Activities: Given the misty and overcast weather, outdoor activities may not be ideal, but the temperature is still quite comfortable for exploring the city. You can consider attending indoor events like the Tribeca Film Festival on June 7th, 2024, where you can enjoy a variety of films from different genres. If you're visiting in September, New York Fashion Week on September 5th, 2024, would be an excellent choice for fashion enthusiasts. For those planning a trip around Thanksgiving, the Macy's Thanksgiving Day Parade on November 28th, 2024, is a must-see event, although you should dress warmly and be prepared for potential rain or colder temperatures during that time of ye ...
#
# Final response from the assistant:
# [
#   {
#     "text": "1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200\u00b0). The current temperature is 25.12\u00b0C, feeling like 25.91\u00b0C, with a high of 26.98\u00b0C and a low of 23.86\u00b0C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.\n\n2. Suggested Activities: Given the misty and overcast weather, outdoor activities may not be ideal, but the temperature is still quite comfortable for exploring the city. You can consider attending indoor events like the Tribeca Film Festival on June 7th, 2024, where you can enjoy a variety of films from different genres. If you're visiting in September, New York Fashion Week on September 5th, 2024, would be an excellent choice for fashion enthusiasts. For those planning a trip around Thanksgiving, the Macy's Thanksgiving Day Parade on November 28th, 2024, is a must-see event, although you should dress warmly and be prepared for potential rain or colder temperatures during that time of year.\n\n3. Outfit Recommendations: Considering the current weather, opt for a light, water-resistant jacket or a sweater to stay comfortable in the misty conditions. Pair it with lightweight pants or jeans and comfortable walking shoes. Since the temperature is mild, layering is key to easily adapt to any changes in weather throughout the day. Don't forget an umbrella to stay dry in case of light rain.\n\n4. Restaurant Recommendations: Unfortunately, the provided information does not include any highly-rated restaurants in New York. However, New York City is known for its diverse culinary scene, offering a wide range of dining options to suit different tastes and budgets. Some popular categories include pizza, bagels, fine dining, and international cuisine. I recommend searching for specific recommendations based on your preferences and location within the city."
#   }
# ]
#
# Final state from checkpointer:
# {
#   "v": 1,
#   "ts": "2024-07-06T00:30:21.462819+00:00",
#   "id": "1ef3b2ee-db8e-6cbf-8004-841987e95ed2",
#   "channel_values": {
#     "city": "New York",
#     "messages": [
#       {
#         "role": "user",
#         "content": [
#           {
#             "text": "What's happening in New York and what should I wear?"
#           }
#         ]
#       },
#       {
#         "role": "assistant",
#         "content": [
#           {
#             "text": "1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200\u00b0). The current temperature is 25.12\u00b0C, feeling like 25.91\u00b0C, with a high of 26.98\u00b0C and a low of 23.86\u00b0C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.\n\n2. Suggested Activities: Given the misty and overcast weather, outdoor activities may not be ideal, but the temperature is still quite comfortable for exploring the city. You can consider attending indoor events like the Tribeca Film Festival on June 7th, 2024, where you can enjoy a variety of films from different genres. If you're visiting in September, New York Fashion Week on September 5th, 2024, would be an excellent choice for fashion enthusiasts. For those planning a trip around Thanksgiving, the Macy's Thanksgiving Day Parade on November 28th, 2024, is a must-see event, although you should dress warmly and be prepared for potential rain or colder temperatures during that time of year.\n\n3. Outfit Recommendations: Considering the current weather, opt for a light, water-resistant jacket or a sweater to stay comfortable in the misty conditions. Pair it with lightweight pants or jeans and comfortable walking shoes. Since the temperature is mild, layering is key to easily adapt to any changes in weather throughout the day. Don't forget an umbrella to stay dry in case of light rain.\n\n4. Restaurant Recommendations: Unfortunately, the provided information does not include any highly-rated restaurants in New York. However, New York City is known for its diverse culinary scene, offering a wide range of dining options to suit different tastes and budgets. Some popular categories include pizza, bagels, fine dining, and international cuisine. I recommend searching for specific recommendations based on your preferences and location within the city."
#           }
#         ]
#       }
#     ],
#     "events_result": "Tribeca Film Festival on 2024-06-07: An annual film festival in Tribeca, Manhattan.\nNew York Fashion Week on 2024-09-05: A semi-annual series of fashion events.\nMacy's Thanksgiving Day Parade on 2024-11-28: An annual parade presented by Macy's on Thanksgiving Day.",
#     "search_result": "",
#     "weather_info": {
#       "city": "New York",
#       "weather": "In New York, the current weather is as follows:\nDetailed status: mist\nWind speed: 5.14 m/s, direction: 200\u00b0\nHumidity: 85%\nTemperature: \n  - Current: 25.12\u00b0C\n  - High: 26.98\u00b0C\n  - Low: 23.86\u00b0C\n  - Feels like: 25.91\u00b0C\nRain: {}\nHeat index: None\nCloud cover: 100%"
#     },
#     "analysis_result": "1. Weather Analysis: New York is currently experiencing misty weather with a high humidity level of 85%. The wind speed is moderate at 5.14 m/s, coming from the southwest direction (200\u00b0). The current temperature is 25.12\u00b0C, feeling like 25.91\u00b0C, with a high of 26.98\u00b0C and a low of 23.86\u00b0C expected for the day. The cloud cover is at 100%, indicating overcast conditions, and there is no heat index or rain in the provided data.\n\n2. Suggested Activities: Given the misty and overcast weather, outdoor activities may not be ideal, but the temperature is still quite comfortable for exploring the city. You can consider attending indoor events like the Tribeca Film Festival on June 7th, 2024, where you can enjoy a variety of films from different genres. If you're visiting in September, New York Fashion Week on September 5th, 2024, would be an excellent choice for fashion enthusiasts. For those planning a trip around Thanksgiving, the Macy's Thanksgiving Day Parade on November 28th, 2024, is a must-see event, although you should dress warmly and be prepared for potential rain or colder temperatures during that time of year.\n\n3. Outfit Recommendations: Considering the current weather, opt for a light, water-resistant jacket or a sweater to stay comfortable in the misty conditions. Pair it with lightweight pants or jeans and comfortable walking shoes. Since the temperature is mild, layering is key to easily adapt to any changes in weather throughout the day. Don't forget an umbrella to stay dry in case of light rain.\n\n4. Restaurant Recommendations: Unfortunately, the provided information does not include any highly-rated restaurants in New York. However, New York City is known for its diverse culinary scene, offering a wide range of dining options to suit different tastes and budgets. Some popular categories include pizza, bagels, fine dining, and international cuisine. I recommend searching for specific recommendations based on your preferences and location within the city.",
#     "restaurant_recommendations": "I'm sorry, but I couldn't find any information about highly-rated restaurants in New York.",
#     "analysis": "analysis"
#   },
#   "channel_versions": {
#     "__start__": 2,
#     "city": 6,
#     "messages": 6,
#     "events_result": 6,
#     "search_result": 6,
#     "weather_info": 6,
#     "analysis_result": 6,
#     "restaurant_recommendations": 6,
#     "start:eventsDB_tool": 3,
#     "eventsDB_tool": 4,
#     "branch:eventsDB_tool:route_events:weather_tool": 4,
#     "weather_tool": 5,
#     "query_restaurants_RAG": 6,
#     "analysis": 6
#   },
#   "versions_seen": {
#     "__start__": {
#       "__start__": 1
#     },
#     "eventsDB_tool": {
#       "start:eventsDB_tool": 2
#     },
#     "search_tool": {},
#     "weather_tool": {
#       "branch:eventsDB_tool:route_events:weather_tool": 3
#     },
#     "query_restaurants_RAG": {
#       "weather_tool": 4
#     },
#     "analysis": {
#       "query_restaurants_RAG": 5
#     }
#   },
#   "pending_sends": []
# }

# %% [markdown]
# ### Analysis of Results
#
# 1. **Tampa, Florida**:
#    - Events: Not found in the local database, triggering the search tool.
#    - Weather: Retrieved from OpenWeatherMap API.
#    - Restaurants: Recommendations provided through the RAG system.
#
# 2. **Philadelphia, Pennsylvania**:
#    - Events: Found in the local database.
#    - Weather: Retrieved from OpenWeatherMap API.
#    - Restaurants: Recommendations provided through the RAG system.
#
# 3. **New York, New York**:
#    - Events: Found in the local database.
#    - Weather: Retrieved from OpenWeatherMap API.
#    - Restaurants: No recommendations available in the RAG system.
#
# #### Similarities:
# - All three cases utilized the weather tool to fetch current weather information.
# - The analysis node provided recommendations based on available data for each city.
#
# #### Differences:
# - Tampa required the use of the search tool for event information, while Philadelphia and New York used the local database.
# - Philadelphia had both local event data and restaurant recommendations, providing the most comprehensive results.
# - New York had local event data but lacked restaurant recommendations, showcasing the system's ability to work with partial information.
#
# #### Key Observations:
# 1. The system adapts to available data sources, seamlessly switching between local and online searches for event information.
# 2. Weather information is consistently provided, forming a core part of the recommendations.
# 3. The RAG system for restaurant recommendations enhances the output when data is available but doesn't hinder the overall functionality when it's not.
# 4. The analysis node demonstrates flexibility in synthesizing varying levels of information to provide useful recommendations.
#
# This multi-city comparison highlights the robustness and adaptability of our multi-agent system, showcasing its ability to provide valuable insights even when faced with varying levels of available information across different cities.

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates the power of multi-agent systems built with LangGraph and powered by Mistral on AWS Bedrock. By combining various data sources and agents, we've created a comprehensive city information system that can provide valuable insights for users.
#
# Our system successfully gathered and analyzed information about events, weather, activities, and dining options for the specified cities. This showcases the potential of using LangGraph to create complex, multi-step workflows that can process and synthesize information from various sources.
